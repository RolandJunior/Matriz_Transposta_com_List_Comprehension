# %%
import re

# %%
s = '-112.265654928602,36.09447672602546,2357\
            -112.2660384528238,36.09342608838671,2357\
            -112.2668139013453,36.09251058776881,2357\
            -112.2677826834445,36.09189827357996,2357\
            -46.980056,-22.058611,456\
            -112.2694810717219,36.0903677207521,2357\
            46.980056,-22.058611,789\
            -112.2690144567276,36.08850916060472,2357\
            -112.2681528815339,36.08753813597956,2357\
            -112.2670588176031,36.08682685262568,2357\
            -112.2657374587321,36.08646312301303,2357'

coord_ex = '(-?\d+\.\d+),'
heig_ex = '(\d+)'
regex = coord_ex + coord_ex + heig_ex

x = re.findall(regex, s)
x
# Out:
# [('-112.265654928602', '36.09447672602546', '2357'),
#  ('-112.2660384528238', '36.09342608838671', '2357'),
#  ('-112.2668139013453', '36.09251058776881', '2357'),
#  ('-112.2677826834445', '36.09189827357996', '2357'),
#  ('-46.980056', '-22.058611', '456'),
#  ('-112.2694810717219', '36.0903677207521', '2357'),
#  ('46.980056', '-22.058611', '789'),
#  ('-112.2690144567276', '36.08850916060472', '2357'),
#  ('-112.2681528815339', '36.08753813597956', '2357'),
#  ('-112.2670588176031', '36.08682685262568', '2357'),
#  ('-112.2657374587321', '36.08646312301303', '2357')]

# %%
for (lat, long, heig) in x:
    print(f'{lat},{long},{heig}')
# Out:
# -112.265654928602,36.09447672602546,2357
# -112.2660384528238,36.09342608838671,2357
# -112.2668139013453,36.09251058776881,2357
# -112.2677826834445,36.09189827357996,2357
# -46.980056,-22.058611,456
# -112.2694810717219,36.0903677207521,2357
# 46.980056,-22.058611,789
# -112.2690144567276,36.08850916060472,2357
# -112.2681528815339,36.08753813597956,2357
# -112.2670588176031,36.08682685262568,2357
# -112.2657374587321,36.08646312301303,2357
